# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv') # read_csv reads a .csv file

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # The flow of a data analysis project
#
# ## 1. get the data - use pandas
# ## 2. clean/preprocess the data - use numpy
# ## 3. visualize/understand the data - use Matplotlib

# %%
# basic analysis

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# setosa, verginica, versicolor
df.groupby('species').mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
# separate the species into 3 separate DataFrames
setosa = df[df['species'] == 'setosa']
versicolor = df[df['species'] == 'versicolor']
virginica = df[df['species'] == 'virginica']

# %%
len(setosa) # len returns number of rows
# Out:
# 50

# %%
len(versicolor)
# Out:
# 50

# %%
len(virginica)
# Out:
# 50

# %%
setosa.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %% [markdown]
# ## Scatterplot - for seeing the distribution of data

# %%
plt.scatter(setosa['sepal_length'], setosa['sepal_width'], c='green')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
plt.scatter(versicolor['sepal_length'], versicolor['sepal_width'], c='blue')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
plt.scatter(virginica['sepal_length'], virginica['sepal_width'], c='red')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %% [markdown]
# ## Histogram - cumulative (how much)

# %%
plt.hist(df['species'], color= 'green')
# Out:
# (array([50.,  0.,  0.,  0.,  0., 50.,  0.,  0.,  0., 50.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## plt.Figure and axes

# %%
fig, ax = plt.subplots(1,3, figsize=(25, 10)) # subplots - creates 1 fugure with axes (rows (1) * column(3))

# %%
ax[0].scatter(virginica['sepal_length'], virginica['sepal_width'], c='blue')
ax[0].set_xlabel('sepal_length')
ax[0].set_ylabel('sepal_width')
# Out:
# Text(4.444444444444452, 0.5, 'sepal_width')

# %%
ax[1].scatter(setosa['sepal_length'], setosa['sepal_width'], c='green')
ax[1].set_xlabel('sepal_length')
ax[1].set_ylabel('sepal_width')
# Out:
# Text(688.2679738562093, 0.5, 'sepal_width')

# %%
ax[2].scatter(versicolor['sepal_length'], versicolor['sepal_width'], c='red')
ax[2].set_xlabel('sepal_length')
ax[2].set_ylabel('sepal_width')
# Out:
# Text(1372.0915032679738, 0.5, 'sepal_width')

# %%
fig

# %% [markdown]
# Display a scatter plot of the iris dataset, with the sepal length on the x-axis and the sepal width on the y-axis.
#
# Create a bar chart of the number of flowers in each species category (setosa, versicolor, and virginica).
#
# Display a scatter plot of the iris dataset, with the petal length on the x-axis and the petal width on the y-axis. Use different colors for each species.
#
# Create a box plot of the sepal length for each species.
#
# Create a histogram of the sepal width, with 10 bins.
#
# Display a scatter plot of the iris dataset, with the sepal length on the x-axis and the petal length on the y-axis. Use different colors for each species.
#
# Create a bar chart of the mean petal length for each species.
#
# Display a scatter plot of the iris dataset, with the petal length on the x-axis and the sepal width on the y-axis. Use different colors for each species.
#
# Create a box plot of the petal width for each species.
#
# Display a scatter plot of the iris dataset, with the sepal length on the x-axis and the petal width on the y-axis. Use different colors for each species.

# %%
plt.scatter(df['sepal_length'], df['sepal_width'], c='red')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
plt.hist(df['species'], color= 'green')
# Out:
# (array([50.,  0.,  0.,  0.,  0., 50.,  0.,  0.,  0., 50.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(1,1, figsize=(8, 8))

# %%
ax.scatter(virginica['sepal_length'], virginica['sepal_width'], c='blue')
ax.scatter(setosa['sepal_length'], setosa['sepal_width'], c='green')
ax.scatter(versicolor['sepal_length'], versicolor['sepal_width'], c='red')

# %%
fig

# %%
plt.boxplot(df['sepal_length'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1284e7190>,
#   <matplotlib.lines.Line2D at 0x1285ac890>],
#  'caps': [<matplotlib.lines.Line2D at 0x1285ad150>,
#   <matplotlib.lines.Line2D at 0x1285ad9d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1280eec90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1285ae1d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x128565d50>],
#  'means': []}

# %% [markdown]
# Create a histogram of the sepal width, with 10 bins.
# Display a scatter plot of the iris dataset, with the sepal length on the x-axis and the petal length on the y-axis. Use different colors for each species.
# Create a bar chart of the mean petal length for each species.
# Display a scatter plot of the iris dataset, with the petal length on the x-axis and the sepal width on the y-axis. Use different colors for each species.
# Create a box plot of the petal width for each species.
# Display a scatter plot of the iris dataset, with the sepal length on the x-axis and the petal width on the y-axis. Use different colors for each species.

# %%
plt.hist(df['sepal_width'], color= 'green')
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['sepal_width'], color= 'green')

# %%
df.groupby('species').mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
petal_mean = df.groupby('species').mean()['petal_length']

# %%
means = petal_mean.values

# %%
means
# Out:
# array([1.462, 4.26 , 5.552])

# %%
plt.hist(means, color= 'green')
# Out:
# (array([1., 0., 0., 0., 0., 0., 1., 0., 0., 1.]),
#  array([1.462, 1.871, 2.28 , 2.689, 3.098, 3.507, 3.916, 4.325, 4.734,
#         5.143, 5.552]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ###Create a box plot of the petal width for each species.
# Display a scatter plot of the iris dataset, with the sepal length on the x-axis and the petal width on the y-axis. Use different colors for each species.

# %%
plt.boxplot(df['petal_width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x161312f10>,
#   <matplotlib.lines.Line2D at 0x161313c10>],
#  'caps': [<matplotlib.lines.Line2D at 0x161314d50>,
#   <matplotlib.lines.Line2D at 0x161314ad0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x13823b990>],
#  'medians': [<matplotlib.lines.Line2D at 0x161315690>],
#  'fliers': [<matplotlib.lines.Line2D at 0x161312890>],
#  'means': []}

# %%
fig, ax = plt.subplots(1,1, figsize=(8, 8))

# %%
ax.scatter(virginica['sepal_length'], virginica['petal_width'], c='blue')
ax.scatter(setosa['sepal_length'], setosa['petal_width'], c='green')
ax.scatter(versicolor['sepal_length'], versicolor['petal_width'], c='red')

# %%
fig
