# %%
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
def strip_dollar(s):
    new_s= s.strip('$')
    return float(new_s)

# %%
change = df['item_price'].apply(strip_dollar)

# %%
df['item_price'] = df['item_price'].apply(strip_dollar)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df.describe()
# Out:
#           order_id     quantity   item_price
# count  4622.000000  4622.000000  4622.000000
# mean    927.254868     1.075725     7.464336
# std     528.890796     0.410186     4.245557
# min       1.000000     1.000000     1.090000
# 25%     477.250000     1.000000     3.390000
# 50%     926.000000     1.000000     8.750000
# 75%    1393.000000     1.000000     9.250000
# max    1834.000000    15.000000    44.250000

# %%
df.iloc[1:10]
# Out:
#    order_id  quantity                              item_name  \
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...

# %%
df.info().max()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.7+ KB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 df.info().max()
#
# AttributeError: 'NoneType' object has no attribute 'max'

# %%
df.groupby('item_name').sum().sort_values('quantity', ascending=False):il
# Out:
#   Cell In[111], line 1
#     df.groupby('item_name').sum().sort_values('quantity', ascending=False):il
#     ^
# SyntaxError: illegal target for annotation

# %%
df.shape[0]
# Out:
# 4622

# %%
df['quantity'].sum()
# Out:
# 4972

# %%
df.groupby('choice_description').sum().sort_values('quantity', ascending=False).head(1)
# Out:
# /var/folders/yq/dj89pjpn4rbcqv2dsyqy3c9h0000gn/T/ipykernel_68708/4189614090.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('choice_description').sum().sort_values('quantity', ascending=False).head(1)
#                     order_id  quantity  item_price
# choice_description
# [Diet Coke]           123455       159      326.71

# %%
df.groupby('choice_description').sum()
# Out:
# /var/folders/yq/dj89pjpn4rbcqv2dsyqy3c9h0000gn/T/ipykernel_68708/4005659708.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('choice_description').sum()
#                                                     order_id  quantity  \
# choice_description
# [Adobo-Marinated and Grilled Chicken, Pinto Bea...       214         1
# [Adobo-Marinated and Grilled Chicken, [Sour Cre...       279         1
# [Adobo-Marinated and Grilled Chicken]                    217         1
# [Adobo-Marinated and Grilled Steak, [Sour Cream...       279         1
# [Adobo-Marinated and Grilled Steak]                      217         1
# ...                                                      ...       ...
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...      2576         2
# ...

# %%
df.groupby('choice_description').count()
# Out:
#                                                     order_id  quantity  \
# choice_description
# [Adobo-Marinated and Grilled Chicken, Pinto Bea...         1         1
# [Adobo-Marinated and Grilled Chicken, [Sour Cre...         1         1
# [Adobo-Marinated and Grilled Chicken]                      1         1
# [Adobo-Marinated and Grilled Steak, [Sour Cream...         1         1
# [Adobo-Marinated and Grilled Steak]                        1         1
# ...                                                      ...       ...
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         2         2
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         1         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         1         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         1         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         1         1
#
#                                                     item_name  item_price
# choice_description
# ...

# %%
df['item_name'].count()
# Out:
# 4622

# %%
(df['quantity'] * df['item_price']).sum()
# Out:
# 39237.02

# %%
df.groupby('order_id').sum()
# Out:
# /var/folders/yq/dj89pjpn4rbcqv2dsyqy3c9h0000gn/T/ipykernel_68708/835378426.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('order_id').sum()
#           quantity  item_price
# order_id
# 1                4       11.56
# 2                2       16.98
# 3                2       12.67
# 4                2       21.00
# 5                2       13.70
# ...            ...         ...
# 1830             2       23.00
# 1831             3       12.90
# 1832             2       13.20
# 1833             2       23.50
# 1834             3       28.75
#
# [1834 rows x 2 columns]

# %%
df.groupby('item_price') > 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 df.groupby('item_price') > 10
#
# TypeError: '>' not supported between instances of 'DataFrameGroupBy' and 'int'

# %%
a = df[df['item_price'] > 10.0]

# %%
a
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %%
len(a)
# Out:
# 1130

# %%
df[['item_price', 'item_name']].sort_values('item_name', ascending=True)
# Out:
#       item_price          item_name
# 3389       12.98  6 Pack Soft Drink
# 341         6.49  6 Pack Soft Drink
# 1849        6.49  6 Pack Soft Drink
# 1860        6.49  6 Pack Soft Drink
# 2713        6.49  6 Pack Soft Drink
# ...          ...                ...
# 2384        8.75  Veggie Soft Tacos
# 781         8.75  Veggie Soft Tacos
# 2851        8.49  Veggie Soft Tacos
# 1699       11.25  Veggie Soft Tacos
# 1395        8.49  Veggie Soft Tacos
#
# [4622 rows x 2 columns]

# %%
(df['item_name'] == 'Veggie Salad Bowl').value_counts()
# Out:
# False    4604
# True       18
# Name: item_name, dtype: int64

# %%
len(df[(df['item_name']== 'Canned Soda') & (df['quantity'])>1])
# Out:
# 0

# %%
multi_canned_soda_orders = df[(df['item_name'] == 'Canned Soda') & (df['quantity'] > 1)]

# %%
len(multi_canned_soda_orders)
# Out:
# 20

# %%
users = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', 
                      sep='|', index_col='user_id')
users.head()
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %%
users['age'].mean()
# Out:
# 34.05196182396607

# %%
users.groupby('occupation').age.agg(['min','max']),
# Out:
# (               min  max
#  occupation
#  administrator   21   70
#  artist          19   48
#  doctor          28   64
#  educator        23   63
#  engineer        22   70
#  entertainment   15   50
#  executive       22   69
#  healthcare      22   62
#  homemaker       20   50
#  lawyer          21   53
#  librarian       23   69
#  marketing       24   55
#  none            11   55
#  other           13   64
#  programmer      20   63
#  retired         51   73
#  salesman        18   66
#  scientist       23   55
#  student          7   42
#  technician      21   55
#  writer          18   60,)
